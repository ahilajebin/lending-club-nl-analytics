# %%
import pandas as pd
df = pd.read_csv("../data/raw/loan.csv", low_memory=False)
#sample
df = df.sample(n=100_000, random_state=42)
df.shape
# Out:
# (100000, 145)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 1758049 to 250989
# Columns: 145 entries, id to settlement_term
# dtypes: float64(105), int64(4), object(36)
# memory usage: 111.4+ MB

# %%
# Top 5 data entries
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1758049 NaN        NaN      35000        35000          35000.0   36 months
# 686533  NaN        NaN      30000        30000          30000.0   60 months
# 900721  NaN        NaN      15000        15000          15000.0   36 months
# 1727912 NaN        NaN      24000        24000          24000.0   60 months
# 539691  NaN        NaN      14400        14400          14400.0   36 months
#
#          int_rate  installment grade sub_grade  ...  \
# 1758049     12.12      1164.51     B        B3  ...
# 686533      10.75       648.54     B        B4  ...
# 900721       7.49       466.53     A        A4  ...
# 1727912     21.15       651.31     E        E2  ...
# 539691       8.59       455.18     A        A5  ...
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 1758049                            NaN                          NaN
# ...

# %%
# Names of all columns
col_names = df.columns
col_names
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %% [markdown]
# Checking the descriptions of some of the columns that I have saved in an excel to understand the data contained in them <br>
# Credit: https://www.kaggle.com/code/pragyanbo/a-hitchhiker-s-guide-to-lending-club-loan-data

# %%
df_description = pd.read_excel('LCDataDictionary.xlsx').dropna()
df_description.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style type="text/css">
# ...

# %%
#Missing Values
missing_val = (df.isnull().mean().sort_values(ascending=False))
missing_val.head(20)
# Out:
# id                                            1.00000
# member_id                                     1.00000
# url                                           1.00000
# orig_projected_additional_accrued_interest    0.99615
# hardship_amount                               0.99525
# hardship_dpd                                  0.99525
# hardship_loan_status                          0.99525
# deferral_term                                 0.99525
# hardship_end_date                             0.99525
# hardship_status                               0.99525
# hardship_start_date                           0.99525
# hardship_reason                               0.99525
# hardship_type                                 0.99525
# hardship_payoff_balance_amount                0.99525
# hardship_last_payment_amount                  0.99525
# hardship_length                               0.99525
# payment_plan_start_date                       0.99525
# ...

# %%
missing_val.shape[0]
# Out:
# 145

# %%
#Cardinality check to find high-cardinality categorical columns
cardinality = df.nunique().sort_values(ascending=False)
cardinality.head(20)
# Out:
# total_pymnt                   93539
# total_pymnt_inv               91672
# total_rec_int                 84542
# tot_cur_bal                   80199
# tot_hi_cred_lim               76140
# total_bal_ex_mort             64163
# last_pymnt_amnt               59691
# total_il_high_credit_limit    54083
# total_rec_prncp               44321
# emp_title                     41348
# total_bal_il                  39921
# revol_bal                     36973
# avg_cur_bal                   34427
# out_prncp_inv                 32979
# out_prncp                     32554
# bc_open_to_buy                30973
# installment                   28433
# max_bal_bc                    16295
# annual_inc                     8896
# recoveries                     7313
# dtype: int64

# %%
cardinality.shape[0]
